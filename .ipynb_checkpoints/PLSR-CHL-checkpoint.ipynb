# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale 
from sklearn.preprocessing import StandardScaler
from sklearn import model_selection
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from scipy.signal import savgol_filter

# %%
data = pd.read_csv('sorghum_2022_whole.csv')

# %%
data =data.loc[data['355'].notnull(), :]

# %%
data = data.loc[data['355']>0 , :]

# %%
data['CHL'] = data[['CHLp1', 'CHLp2', 'CHLp3']].mean(axis=1)

# %%
data
# Out:
#      Genotype ID  Accession  Genotype  Rep  Leaf_num  CHLp1  CHLp2  CHLp3  \
# 0      GREENLEAF  PI 659692         1    1       1.0  367.4  472.9  399.7
# 1      GREENLEAF  PI 659692         1    1       1.0  367.4  472.9  399.7
# 2      GREENLEAF  PI 659692         1    1       1.0  367.4  472.9  399.7
# 3      GREENLEAF  PI 659692         1    1       2.0  399.7  739.3  357.8
# 4      GREENLEAF  PI 659692         1    1       2.0  399.7  739.3  357.8
# ...          ...        ...       ...  ...       ...    ...    ...    ...
# 1048     RTx2909  PI 598 69        68    2       2.0  252.7  308.1  389.5
# 1049     RTx2909  PI 598 69        68    2       2.0  252.7  308.1  389.5
# 1050     RTx2909  PI 598 69        68    2       3.0  232.1  283.0  388.4
# 1051     RTx2909  PI 598 69        68    2       3.0  232.1  283.0  388.4
# 1052     RTx2909  PI 598 69        68    2       3.0  232.1  283.0  388.4
#
#         FW      LA  ...      2492     2493    2494      2495      2496  \
# 0     4.45  281.59  ...  0.071300  0.07070  0.0698  0.069483  0.070500
# 1     4.45  281.59  ...  0.074300  0.07400  0.0743  0.074400  0.074160
# 2     4.45  281.59  ...  0.061000  0.06050  0.0597  0.059500  0.059300
# 3     3.45  225.36  ...  0.075948  0.07540  0.0729  0.072100  0.072000
# 4     3.45  225.36  ...  0.082870  0.08230  0.0813  0.080900  0.079900
# ...    ...     ...  ...       ...      ...     ...       ...       ...
# 1048  9.05  341.73  ...  0.055500  0.05510  0.0554  0.055000  0.055200
# 1049  9.05  341.73  ...  0.055500  0.05500  0.0544  0.054274  0.054787
# 1050  8.80  352.01  ...  0.065900  0.06560  0.0649  0.065000  0.065000
# 1051  8.80  352.01  ...  0.054600  0.05429  0.0534  0.053100  0.052700
# 1052  8.80  352.01  ...  0.063900  0.06380  0.0632  0.062800  0.061400
#
#         2497      2498      2499      2500         CHL
# 0     0.0701  0.068500  0.068300  0.068400  413.333333
# 1     0.0736  0.072400  0.072600  0.074100  413.333333
# 2     0.0587  0.058200  0.058200  0.058000  413.333333
# 3     0.0717  0.072600  0.072600  0.072200  498.933333
# 4     0.0796  0.081200  0.081600  0.081600  498.933333
# ...      ...       ...       ...       ...         ...
# 1048  0.0557  0.055997  0.055600  0.055200  316.766667
# 1049  0.0547  0.054600  0.054600  0.054132  316.766667
# 1050  0.0645  0.064445  0.064130  0.062700  301.166667
# 1051  0.0525  0.053000  0.052844  0.052400  301.166667
# 1052  0.0608  0.061000  0.060900  0.061000  301.166667
#
# [1044 rows x 2164 columns]

# %%
import copy
data_test = copy.deepcopy(data)

data_test.head()

my_group = data_test.groupby(['Genotype', 'Rep']).mean()

my_group.head()
# Out:
#               Leaf_num       CHLp1       CHLp2       CHLp3         FW  \
# Genotype Rep
# 1        1         2.0  402.100000  524.833333  368.400000   3.183333
#          2         2.0  368.433333  323.066667  254.166667   2.683333
# 2        1         1.5  778.500000  750.350000  631.400000  16.000000
#          2         2.0  581.900000  429.000000  216.466667  16.483333
# 4        1         2.0  510.433333  557.733333  555.100000  13.833333
#
#                       LA  Leaf_pos       350       351       352  ...  \
# Genotype Rep                                                      ...
# 1        1    210.663333       2.0  0.127347  0.114354  0.101045  ...
#          2    175.103333       2.0  0.121162  0.122988  0.112401  ...
# 2        1    617.350000       2.0  0.113189  0.126603  0.126120  ...
#          2    630.256667       2.0  0.108398  0.112435  0.107573  ...
# 4        1    596.180000       2.0  0.135304  0.123428  0.107437  ...
#
#                   2492      2493      2494      2495      2496      2497  \
# Genotype Rep
# 1        1    0.074093  0.073731  0.073122  0.072774  0.072529  0.072144
#          2    0.072218  0.071893  0.071624  0.071518  0.071791  0.071510
# 2        1    0.045160  0.044659  0.043533  0.043155  0.042783  0.042633
#          2    0.044433  0.044253  0.043939  0.043714  0.043111  0.042863
# 4        1    0.064289  0.064083  0.063794  0.063567  0.063478  0.063435
#
#                   2498      2499      2500         CHL
# Genotype Rep
# 1        1    0.071700  0.071611  0.071944  431.777778
#          2    0.070941  0.070632  0.069888  315.222222
# 2        1    0.043460  0.043559  0.043034  720.083333
#          2    0.043029  0.043048  0.042944  409.122222
# 4        1    0.063330  0.063222  0.063345  541.088889
#
# [5 rows x 2159 columns]

# %%
y = my_group.loc[: ,'CHL']

# %%
X_total = my_group.iloc[:, 7:2158]

# %%
X_total.drop(columns = X_total.columns[0:100], inplace = True)
# Out:
# /home/schnable/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
X_total
# Out:
#                    450       451       452       453       454       455  \
# Genotype Rep
# 1        1    0.063522  0.063981  0.064120  0.064415  0.064867  0.064756
#          2    0.083090  0.083374  0.082956  0.082938  0.083556  0.084085
# 2        1    0.058764  0.058700  0.058267  0.058035  0.058200  0.058660
#          2    0.048535  0.048478  0.048178  0.048233  0.048740  0.048918
# 4        1    0.068367  0.068070  0.068589  0.069044  0.068944  0.068633
# ...                ...       ...       ...       ...       ...       ...
# 66       1    0.099893  0.100610  0.101008  0.101394  0.101838  0.102013
#          2    0.075186  0.075989  0.076267  0.076411  0.076719  0.077338
# 67       2    0.084809  0.085060  0.085800  0.086108  0.086063  0.086951
# 68       1    0.052522  0.052322  0.052622  0.053099  0.053477  0.053764
#          2    0.047686  0.047611  0.047766  0.048137  0.048561  0.048756
#
#                    456       457       458       459  ...      2491      2492  \
# Genotype Rep                                          ...
# 1        1    0.064767  0.065000  0.065256  0.064900  ...  0.074209  0.074093
#          2    0.084164  0.084198  0.084582  0.084875  ...  0.072651  0.072218
# 2        1    0.059227  0.059433  0.059083  0.059113  ...  0.045457  0.045160
#          2    0.049146  0.049285  0.049167  0.049423  ...  0.044278  0.044433
# 4        1    0.068389  0.068796  0.069764  0.069411  ...  0.064662  0.064289
# ...                ...       ...       ...       ...  ...       ...       ...
# 66       1    0.102350  0.102878  0.103481  0.103581  ...  0.087074  0.086616
#          2    0.077648  0.077595  0.077472  0.078088  ...  0.064874  0.064473
# 67       2    0.087080  0.086999  0.087456  0.087802  ...  0.074328  0.074142
# 68       1    0.054113  0.054189  0.053901  0.054333  ...  0.070356  0.069540
#          2    0.049022  0.049056  0.048816  0.049213  ...  0.058822  0.058456
#
#                   2493      2494      2495      2496      2497      2498  \
# Genotype Rep
# 1        1    0.073731  0.073122  0.072774  0.072529  0.072144  0.071700
#          2    0.071893  0.071624  0.071518  0.071791  0.071510  0.070941
# 2        1    0.044659  0.043533  0.043155  0.042783  0.042633  0.043460
#          2    0.044253  0.043939  0.043714  0.043111  0.042863  0.043029
# 4        1    0.064083  0.063794  0.063567  0.063478  0.063435  0.063330
# ...                ...       ...       ...       ...       ...       ...
# 66       1    0.086369  0.085814  0.085228  0.084951  0.084582  0.083503
#          2    0.064240  0.063900  0.063589  0.063533  0.063400  0.063154
# 67       2    0.073891  0.074272  0.074044  0.073078  0.072771  0.072822
# 68       1    0.069076  0.068956  0.068625  0.068402  0.068133  0.067705
#          2    0.058066  0.057344  0.057075  0.057010  0.056844  0.057127
#
#                   2499      2500
# Genotype Rep
# 1        1    0.071611  0.071944
#          2    0.070632  0.069888
# 2        1    0.043559  0.043034
#          2    0.043048  0.042944
# 4        1    0.063222  0.063345
# ...                ...       ...
# 66       1    0.083202  0.083970
#          2    0.063102  0.063589
# 67       2    0.072533  0.072333
# 68       1    0.067379  0.067107
#          2    0.056885  0.055926
#
# [120 rows x 2051 columns]

# %%
#plt.plot(X_total.T)

# %%
column_filter = np.arange(0,2050,5)  ## creating an index for column filtering
X= X_total.iloc[:, column_filter] # selecting the filtered columns

# %%
X[X.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [450, 455, 460, 465, 470, 475, 480, 485, 490, 495, 500, 505, 510, 515, 520, 525, 530, 535, 540, 545, 550, 555, 560, 565, 570, 575, 580, 585, 590, 595, 600, 605, 610, 615, 620, 625, 630, 635, 640, 645, 650, 655, 660, 665, 670, 675, 680, 685, 690, 695, 700, 705, 710, 715, 720, 725, 730, 735, 740, 745, 750, 755, 760, 765, 770, 775, 780, 785, 790, 795, 800, 805, 810, 815, 820, 825, 830, 835, 840, 845, 850, 855, 860, 865, 870, 875, 880, 885, 890, 895, 900, 905, 910, 915, 920, 925, 930, 935, 940, 945, ...]
# Index: []
#
# [0 rows x 410 columns]

# %%
#define the cv
cv = RepeatedKFold(n_splits=10)
rmse = []

# %%
#Calculate MSE using cross-validation, adding one component at a time
for i in np.arange(1, 40):
    pls = PLSRegression(n_components=i)
    score = -1*model_selection.cross_val_score(pls, X, y, cv=cv,
               scoring='neg_mean_squared_error').mean()
    rmse.append(np.sqrt(score))

# %%
n_comp = rmse.index(min(rmse)) +1

# %%
# split the dataset into training (60%) and testing (40%) sets
X_train,X_test,y_train,y_test = train_test_split(X, y ,test_size=0.4)

# %%
### calculate RMSE
pls = PLSRegression(n_components=n_comp)
pls.fit(X_train, y_train)
# Out:
# PLSRegression(n_components=16)

# %%
np.sqrt(mean_squared_error(y_test, pls.predict(X_test)))
# Out:
# 65.61148125638881

# %%
y_pred = pls.predict(X_test)

# %%
plt.scatter(y_test, y_pred)
plt.ylabel('Predicted CHL values')
plt.xlabel('Ground truth LWC measurements')
sns.regplot(x = y_test , y = y_pred)
# Out:
# <AxesSubplot:xlabel='CHL', ylabel='Predicted CHL values'>

# %%
from scipy.stats import pearsonr, spearmanr
y_pred2 = [x[0] for x in y_pred]

r, p = spearmanr(y_test, y_pred2)
r2 = r**2
print(r2, p)
# Out:
# 0.7162024499751026 3.6005149800582254e-14
